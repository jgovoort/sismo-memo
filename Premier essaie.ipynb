# %%
import obspy

# %%
import msnoise
import matplotlib.pyplot as plt

# %%
test = obspy.read("D:/Glacial/453020732.2.2022.05.28.00.00.00.000.N.miniseed")

# %%
print(test)
# Out:
# 1 Trace(s) in Stream:
# SS.20732..D_P | 2022-05-28T00:00:00.000000Z - 2022-05-29T00:00:00.000000Z | 250.0 Hz, 21600001 samples

# %%
test.plot()
