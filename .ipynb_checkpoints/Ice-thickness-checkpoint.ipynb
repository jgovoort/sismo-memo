# %% [markdown]
# # Determining the Ice thickness of Vatnajokull based on H/V spectral ratio

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
root = "D:\MEMOIRE\Ice_thickness"
alt_glacier = '\point_altitude_glacier\point_altitude_glacier.csv'
station = "\lt_nodes_ablation_lambert.csv"

# %%
with open(root+alt_glacier) as file :
    glac_alt = []
    pos = []
    line = 0
    readcsv = csv.reader(file, delimiter=',')
    for row in readcsv :
        if line > 0 :
            glac_alt.append(float(row[-1]))
            pos.append(float(row[3])/1000)
        line += 1

# %%
filepath = root+station
print(filepath)
with open(filepath) as file :
    stt = []
    pos = []
    readcsv = csv.reader(file, delimiter=',')
    i = 0
    line = 0
    for row in readcsv :
        if line > 0 :
            stt.append([row[1]])
            stt[i].extend(row[4:7])
            i += 1
        line += 1
    print(stt)
# Out:
# D:\MEMOIRE\Ice_thickness\lt_nodes_ablation_lambert.csv
# [['20739', '1769274.68255682', '1227414.53980666', '1445'], ['20754', '1772111.64287197', '1232383.33887074', '1505'], ['20769', '1757998.30222875', '1219120.85828483', '1159'], ['20773', '1756930.67057778', '1205501.31065622', '852'], ['20774', '1763952.64283821', '1223207.58530924', '1294'], ['20781', '1757497.77467811', '1211646.50005961', '1010']]

# %%
def sortThird(val):
    return val[2]
stt.sort(key=sortThird)
print(stt)
# Out:
# [['20773', '1756930.67057778', '1205501.31065622', '852'], ['20781', '1757497.77467811', '1211646.50005961', '1010'], ['20769', '1757998.30222875', '1219120.85828483', '1159'], ['20774', '1763952.64283821', '1223207.58530924', '1294'], ['20739', '1769274.68255682', '1227414.53980666', '1445'], ['20754', '1772111.64287197', '1232383.33887074', '1505']]

# %%
plt.figure(figsize=(15, 5), dpi=300)
plt.plot(pos, glac_alt)
plt.xlabel('Distance from the first node (Km)')
plt.ylabel('Altitude (m)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
