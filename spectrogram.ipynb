# %% [markdown]
# # Spectrogram

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy
import math
import datetime
import time
import obspy

# %%
trace = obspy.read('D:\\Nodes_ablation_zone\\All_comp_DP_\\453020781.3.2022.05.08.00.00.00.000.Z.miniseed')

# %%
trace[0].stats.npts/24
# Out:
# 900000.0416666666

# %%
fig = plt.figure(figsize=(17,5))
ax = fig.add_axes([1, 1, 1, 1])


fig = trace.spectrogram(wlen=60, samp_rate=250, per_lap=0, dbscale=True, show=False, axes=ax)
#ax = fig.axes[0]
ax.set_ylim(1,20)

plt.show()
